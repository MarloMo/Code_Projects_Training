# %% [markdown]
# ## **Day in the Life**
#
# * Calculating the Net Present Value of two different projects
# * Analyzing the performance of individual stocks against industry benchmarks; and
# * Reviewing a portfolio of equities to choose the best option for a given level of risk

# %% [markdown]
# ## **Calculating Net Present Value (NVP)**
#
# Frances is working with her team to evaluate two projects they are thinking about pursuing, but they can’t do both. Frances needs to help her team decide how to allocate their investment.
#
# Calculating the Net Present Value (NPV) will help us analyze the profitability of these two projects by giving us a present value of the future cash inflows and outflows over the life of both projects.
#
# $$
# NPV = \sum_{t=0}^{n} \frac{(CF)_{t}}{(1+r)^{t}}
# $$
#
# Python can easily calculate the NPV of a set of cash flows. Since any NPV calculation is dependent on $r$, the rate at which we are discounting future cash flows to the present, it can be useful to calculate different NPVs at different discount rates, and build an NPV profile to see how the NPV of a project changes based upon the discount rate applied to the calculation.
#
# Frances is asked to create NPV profiles for two projects her team is evaluating to determine which project they should choose. SuperBank has $1,000,000 available to invest, and two clean energy projects available for investment that will generate annual cash flows over 20 years. By building and graphing an NPV Profile, she can easily see how discount rates affect both projects and help her team make a good decision.
#
# Project A is represented by the red line on the chart, and Project B is represented by the blue line.

# %%
# import codecademylib3_seaborn
import matplotlib.pyplot as plt


def calculate_npv(rate, cash_flow):
    npv = 0
    for t in range(len(cash_flow)):
        npv += cash_flow[t] / (1 + rate)**t
    return npv


# Remember that an investment is an outflow, and must be a negative number.
# In this case starting at $1,000,000
project_a = [
    -1000000,
    0,
    0,
    50000,
    50000,
    200000,
    250000,
    250000,
    250000,
    250000,
    375000,
    375000,
    375000,
    375000,
    375000,
    250000,
    250000,
    250000,
    250000,
    100000,
]

# Update Project B Cash Flows Here
project_b = [
    -1000000,
    50000,
    50000,
    50000,
    50000,
    250000,
    500000,
    500000,
    500000,
    500000,
    100000,
    100000,
    100000,
    100000,
    100000,
    100000,
    100000,
    100000,
    100000,
    100000,
]

discount_rate = [
    0.05,
    0.055,
    0.06,
    0.065,
    0.07,
    0.075,
    0.08,
    0.085,
    0.09,
    0.095,
    0.1,
    0.105,
    0.11,
    0.115,
    0.12,
    0.125,
    0.13,
    0.135,
    0.14,
    0.145,
    0.15,
    0.155,
    0.16,
    0.165,
    0.17,
    0.175,
    0.18,
]


npvs_a = list()
npvs_b = list()
for rate in discount_rate:
    npv_a = calculate_npv(rate, project_a)
    npvs_a.append(npv_a)
    npv_b = calculate_npv(rate, project_b)
    npvs_b.append(npv_b)

plt.plot(discount_rate, npvs_a, linewidth=2.0, color="red", label="Project A")
plt.plot(discount_rate, npvs_b, linewidth=2.0, color="blue", label="Project B")
plt.axhline(y=0, linewidth=0.5, color="black")
plt.title("NPV Profile for Projects A and B")
plt.xlabel("Discount Rate")
plt.ylabel("Net Present Value")
plt.legend()
plt.show()

# %% [markdown]
# At 6%, Project A is more profitable and at 12%, Project B is more profitable.

# %%
### Testing Grounds


def my_calculate_npv(rate, cash_flow):
    result = sum(cash_flow[t] / (1 + rate)**t for t in range(len(cash_flow)))

    return result


result_1 = []
for rate in discount_rate:
    result_1.append(calculate_npv(rate, project_a))

result_2 = []
for rate in discount_rate:
    result_2.append(my_calculate_npv(rate, project_a))

print(result_1)
print(result_2)
# Out:
# [1469485.5987220989, 1345755.3749658675, 1229559.9634034368, 1120373.1640259805, 1017709.5591643129, 921121.075872193, 830193.8592528757, 744545.4268313957, 663822.0771092902, 587696.5281498685, 515865.7644656773, 448049.0726483359, 383986.2481216673, 323435.957137821, 266174.23969413055, 211993.14044612972, 160699.45594609514, 112113.5876627192, 66068.49124924328, 22408.71343701897, -19010.491250239127, -58323.9710297188, -95657.42104520067, -131128.06701229612, -164845.29359133536, -196911.22226980387, -227421.24309716834]
# [1469485.5987220986, 1345755.3749658673, 1229559.9634034368, 1120373.1640259807, 1017709.5591643129, 921121.075872193, 830193.8592528758, 744545.4268313957, 663822.0771092899, 587696.5281498686, 515865.76446567744, 448049.07264833583, 383986.2481216672, 323435.9571378211, 266174.23969413043, 211993.14044612984, 160699.45594609514, 112113.58766271919, 66068.49124924332, 22408.71343701883, -19010.491250239007, -58323.971029718974, -95657.42104520065, -131128.06701229606, -164845.2935913354, -196911.22226980378, -227421.24309716836]
